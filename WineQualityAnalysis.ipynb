# %% [markdown]
# # MINOR PROJECT

# %% [markdown]
# # Step 1 : Importing dataset

# %%
# Importing Packages for performing mathematical operations and importing the dataset
import numpy as np
import pandas as pd

# %%
# Importing dataset which is in the form of CSV File
data = pd.read_csv("datasets_4458_8204_winequality-red.csv")

# %%
# Printing first five rows
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # Step 2 : Data Quality check

# %%
# Checking NA values column-wise
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# We can see that no column contains NA values
# So we don't need to drop any rows
# But if NA case arises, uncomment the line below
# data.dropna(inplace=True)

# %%
# Getting the dimensions of cleaned data
data.shape
# Out:
# (1599, 12)

# %% [markdown]
# # Step 3 : Exploratory Data Analysis

# %%
# Importing packages for Visual Representation of data
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# Histograms :

# %%
sns.set()
plt.hist(data['fixed acidity'], color='gold', edgecolor='orange', linewidth=1)
plt.title('Plot showing Fixed Acidity')
plt.xlabel('Fixed Acidity')
plt.ylabel('Number of Observations')
plt.xticks([2,4,6,8,10,12,14,16])
plt.show()

# %%
sns.set()
plt.hist(data['volatile acidity'], bins = 5, color='cyan', edgecolor='turquoise', linewidth=1)
plt.title('Plot showing Volatile Acidity')
plt.xlabel('Volatile Acidity')
plt.ylabel('Number of Observations')
plt.show()

# %%
sns.set()
plt.hist(data['citric acid'], color='violet', edgecolor='darkmagenta', linewidth=1)
plt.title('Plot showing Citric Acid Concentration')
plt.xlabel('Citric Acid Concentration')
plt.ylabel('Number of Observations')
plt.show()

# %%
sns.set()
plt.hist(data['free sulfur dioxide'], color='lemonchiffon', edgecolor='khaki', linewidth=1)
plt.title('Plot showing Free Sulfur Dioxide Concentration')
plt.xlabel('Free Sulfur Dioxide Concentration')
plt.ylabel('Number of Observations')
plt.show()

# %%
sns.set()
plt.hist(data['pH'], color='palegreen', edgecolor='yellowgreen', linewidth=1)
plt.title('Plot showing pH')
plt.xlabel('pH')
plt.ylabel('Number of Observations')
plt.show()

# %%
sns.set()
plt.hist(data['sulphates'], color='lightsalmon', edgecolor='tomato', linewidth=1)
plt.title('Plot showing Sulphates Concentration')
plt.xlabel('Sulphates Concentration')
plt.ylabel('Number of Observations')
plt.show()

# %% [markdown]
# Boxplots :

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[0]], orient = 'vertical', width = 0.4, color = 'rosybrown')
plt.ylabel('Values of Fixed Acidity')
plt.title('Plot showing the Distribution of Fixed Acidity')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[1]], orient = 'vertical', width = 0.4, color = 'lightcoral')
plt.ylabel('Values of Volatile Acidity')
plt.title('Plot showing the Distribution of Volatile Acidity')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[2]], orient = 'vertical', width = 0.4, color = 'coral')
plt.ylabel('Concentration of Citric Acid')
plt.title('Plot showing the Distribution of Concentration of Citric Acid')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[3]], orient = 'vertical', width = 0.4, color = 'antiquewhite')
plt.ylabel('Concentration of Residual Sugar')
plt.title('Plot showing the Distribution of Concentration of Residual Sugar')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[4]], orient = 'vertical', width = 0.4, color = 'wheat')
plt.ylabel('Concentration of Chlorides')
plt.title('Plot showing the Distribution of Concentration of Chlorides')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[5]], orient = 'vertical', width = 0.4, color = 'yellowgreen')
plt.ylabel('Concentration of Free Sulfur Dioxide')
plt.title('Plot showing the Distribution of Concentration of Free Sulfur Dioxide')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[6]], orient = 'vertical', width = 0.4, color = 'palegreen')
plt.ylabel('Concentration of Total Sulfur Dioxide')
plt.title('Plot showing the Distribution of Concentration of Total Sulfur Dioxide')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[7]], orient = 'vertical', width = 0.4, color = 'mediumspringgreen')
plt.ylabel('Values of Density')
plt.title('Plot showing the Values of density of different samples')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[8]], orient = 'vertical', width = 0.4, color = 'aquamarine')
plt.ylabel('Values of pH')
plt.title('Plot showing the values of pH of different smaples')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[9]], orient = 'vertical', width = 0.4, color = 'mediumturquoise')
plt.ylabel('Concentration of Sulphates')
plt.title('Plot showing the Distribution of Concentration of Sulphates')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[10]], orient = 'vertical', width = 0.4, color = 'slateblue')
plt.ylabel('Concentration of Alcohol')
plt.title('Plot showing the Distribution of Concentration of Alcohol')
plt.show()

# %%
sns.set()
sns.boxplot(data=data.iloc[:,[11]], orient = 'vertical', width = 0.4, color = 'paleturquoise')
plt.ylabel('Quality')
plt.title('Plot showing the Quality of different samples')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Scatter Plots :

# %%
sns.set()
plt.scatter(data['citric acid'].values, data['fixed acidity'].values, s = 20, c=data['quality'].values)
plt.xlabel('Concentration of Citric Acid')
plt.ylabel('Values of Fixed Acidity')
plt.title('Fixed Acidity Vs Concentration of Citric Acid')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data['volatile acidity'].values, data['chlorides'].values, s = 20, c=data['quality'].values)
plt.xlabel('Values of Volatile Acidity')
plt.ylabel('Concentration of Chlorides')
plt.title('Concentration of Chlorides Vs Values of Volatile Acidity')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data['fixed acidity'].values, data['pH'].values, s = 20, c=data['quality'].values)
plt.xlabel('Values of Fixed Acidity')
plt.ylabel('pH')
plt.title('pH Vs Fixed Acidity')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data['fixed acidity'].values, data['residual sugar'].values, s = 20, c=data['quality'].values)
plt.xlabel('Values of Fixed Acidity')
plt.ylabel('Concentration of Residual Sugar')
plt.title('Concentration of Residual Sugar Vs Fixed Acidity')
plt.margins(0.02)
plt.show()

# %%
sns.set()
plt.scatter(data['free sulfur dioxide'].values, data['total sulfur dioxide'].values, s = 20, c=data['quality'].values)
plt.xlabel('Concentration of Free Sulfur Dioxide')
plt.ylabel('Concentration of Total Sulfur Dioxide')
plt.title('Concentration of Total Sulfur Dioxide Vs Free Sulfur Dioxide')
plt.margins(0.02)
plt.show()

# %% [markdown]
# # Step 4 : Data Modelling

# %% [markdown]
# # Implementing K-Nearest Neighbors Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
# Instantiation
knn = KNeighborsClassifier(n_neighbors = 24)   # 24 is chosen due to hyperparameter tuning and gives maximum accuracy

# Selecting the data
X = data.drop(['quality'], axis = 1).values  # Feature Variables
y = data['quality'].values     # Target Variables

# Implementing Train-test split
from sklearn.model_selection import train_test_split
# We perform hyperparameter tuning during Train-test split and choose the optimum values to provide maximum accuracy
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 64, stratify = y)

# Fitting the model
knn.fit(X_train, y_train)

# Calculating and printing the accuracy of the model
accuracy1 = knn.score(X_test, y_test) * 100
print("Accuracy of the model while using K-Nearest Neighbors is " + str(accuracy1))
# Out:
# Accuracy of the model while using K-Nearest Neighbors is 61.25000000000001

# %% [markdown]
# # Implementing Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
# Instantiation
logreg = LogisticRegression()

# Dimensionality Reduction for increasing the accuracy of the model
X = data.iloc[:,[1,2,3,4,5,8,9,10]].values     # Feature Variables
y = data['quality'].values     # Target Variable

# Implementing Train-test split
from sklearn.model_selection import train_test_split
# We perform hyperparameter tuning during Train-test split and choose the optimum values to provide maximum accuracy
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 25, stratify = y)

# Fitting the model
logreg.fit(X_train, y_train)

# Calculating and printing the accuracy of the model
accuracy2 = logreg.score(X_test, y_test) * 100
print("Accuracy of the model while using Linear Regression is " + str(accuracy2))
# Out:
# Accuracy of the model while using Linear Regression is 64.58333333333334
# C:\Users\Md Ilmul Hoda\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Md Ilmul Hoda\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
